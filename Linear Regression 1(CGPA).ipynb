# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("C:\\Users\\admin\\Documents\\Jayapriyan A\\Admission_Predict.csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
GA.shape
# Out:
# (400, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
newdataset=GA.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','University Rating','SOP','LOR ','Research'],axis=1)

# %%
newdataset
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 395  9.04              0.82
# 396  9.11              0.84
# 397  9.45              0.91
# 398  8.78              0.67
# 399  9.66              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[9.65],
#        [8.87],
#        [8.  ],
#        [8.67],
#        [8.21],
#        [9.34],
#        [8.2 ],
#        [7.9 ],
#        [8.  ],
#        [8.6 ],
#        [8.4 ],
#        [9.  ],
#        [9.1 ],
#        [8.  ],
#        [8.2 ],
#        [8.3 ],
#        [8.7 ],
#        [8.  ],
#        [8.8 ],
#        [8.5 ],
#        [7.9 ],
#        [8.4 ],
#        [9.5 ],
#        [9.7 ],
#        [9.8 ],
#        [9.6 ],
#        [8.8 ],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('CGPA')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (280, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
x_train
# Out:
# array([[8.03],
#        [8.45],
#        [9.31],
#        [8.27],
#        [7.56],
#        [9.44],
#        [9.5 ],
#        [8.54],
#        [8.27],
#        [7.8 ],
#        [9.43],
#        [8.76],
#        [9.02],
#        [7.68],
#        [8.97],
#        [8.12],
#        [9.18],
#        [8.76],
#        [8.02],
#        [8.  ],
#        [9.01],
#        [8.68],
#        [8.1 ],
#        [8.45],
#        [8.79],
#        [8.47],
#        [7.64],
#        [9.02],
#        [9.23],
#        [8.62],
#        [8.66],
#        [9.56],
#        [9.  ],
#        [8.34],
#        [9.36],
#        [8.45],
#        [8.96],
#        [9.32],
#        [8.43],
#        [8.65],
#        [9.11],
#        [8.78],
#        [9.6 ],
#        [7.65],
#        [8.5 ],
#        [9.8 ],
#        [8.33],
#        [8.96],
#        [8.66],
#        [8.2 ],
#        [8.27],
#        [8.79],
#        [8.54],
#        [8.65],
#        [8.65],
#        [9.08],
#        [9.38],
#        [9.3 ],
# ...

# %%
y_train
# Out:
# array([[0.34],
#        [0.71],
#        [0.91],
#        [0.69],
#        [0.47],
#        [0.92],
#        [0.94],
#        [0.71],
#        [0.74],
#        [0.64],
#        [0.93],
#        [0.77],
#        [0.61],
#        [0.6 ],
#        [0.84],
#        [0.64],
#        [0.84],
#        [0.77],
#        [0.63],
#        [0.65],
#        [0.81],
#        [0.84],
#        [0.65],
#        [0.59],
#        [0.7 ],
#        [0.57],
#        [0.7 ],
#        [0.81],
#        [0.88],
#        [0.56],
#        [0.8 ],
#        [0.94],
#        [0.79],
#        [0.62],
#        [0.93],
#        [0.76],
#        [0.78],
#        [0.85],
#        [0.7 ],
#        [0.71],
#        [0.8 ],
#        [0.79],
#        [0.9 ],
#        [0.56],
#        [0.67],
#        [0.94],
#        [0.74],
#        [0.86],
#        [0.76],
#        [0.47],
#        [0.64],
#        [0.81],
#        [0.73],
#        [0.71],
#        [0.73],
#        [0.89],
#        [0.93],
#        [0.86],
# ...

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(x_test)

# %%
y_predict
# Out:
# array([[0.71508479],
#        [0.72351448],
#        [0.75723323],
#        [0.65186214],
#        [0.75091096],
#        [0.6181434 ],
#        [0.74248128],
#        [0.61603597],
#        [0.88367853],
#        [0.89632306],
#        [0.55492075],
#        [0.86681916],
#        [0.71508479],
#        [0.43901255],
#        [0.82888557],
#        [0.66029183],
#        [0.63500277],
#        [0.83942267],
#        [0.57388754],
#        [0.74248128],
#        [0.8415301 ],
#        [0.83731525],
#        [0.696118  ],
#        [0.45797935],
#        [0.78041487],
#        [0.60549887],
#        [0.50012778],
#        [0.66029183],
#        [0.84785236],
#        [0.64975472],
#        [0.60549887],
#        [0.71297737],
#        [0.73405159],
#        [0.60339144],
#        [0.79095198],
#        [0.74880354],
#        [0.58020981],
#        [0.85628205],
#        [0.65396957],
#        [0.94690118],
#        [0.69401058],
#        [0.65396957],
#        [0.63921761],
# ...

# %%
COMP=pd.DataFrame(x_test,columns=['CGPA'])

# %%
COMP
# Out:
#      CGPA
# 0    8.56
# 1    8.60
# 2    8.76
# 3    8.26
# 4    8.73
# ..    ...
# 115  9.26
# 116  9.34
# 117  8.40
# 118  8.37
# 119  8.13
#
# [120 rows x 1 columns]

# %%
COMP['AVLDATA']=y_test

# %%
COMP
# Out:
#      CGPA  AVLDATA
# 0    8.56     0.71
# 1    8.60     0.70
# 2    8.76     0.79
# 3    8.26     0.73
# 4    8.73     0.72
# ..    ...      ...
# 115  9.26     0.91
# 116  9.34     0.90
# 117  8.40     0.78
# 118  8.37     0.70
# 119  8.13     0.59
#
# [120 rows x 2 columns]

# %%
COMP['PRDDATA']=y_test

# %%
COMP
# Out:
#      CGPA  AVLDATA  PRDDATA
# 0    8.56     0.71     0.71
# 1    8.60     0.70     0.70
# 2    8.76     0.79     0.79
# 3    8.26     0.73     0.73
# 4    8.73     0.72     0.72
# ..    ...      ...      ...
# 115  9.26     0.91     0.91
# 116  9.34     0.90     0.90
# 117  8.40     0.78     0.78
# 118  8.37     0.70     0.70
# 119  8.13     0.59     0.59
#
# [120 rows x 3 columns]

# %%
pt.scatter(x,y,color='red')
pt.plot(x_test,y_predict,color='green')
pt.xlabel('CGPA')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.005574931139058401

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.05393717082765783
